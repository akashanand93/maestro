# %%
from dataloader import csv_to_npy
# %load_ext autoreload
# %autoreload 2

# %%
data_dir = "/Users/shiva/Desktop/data_maestro"
channel = 'open'
mode = 'train'

# %%
a = csv_to_npy(data_dir, channel, mode)
# Out:
#      instrument                                               open
# 0          1793  [602.75, 600.75, 604.6, 601.25, 600.95, 602.85...
# 1          3329  [2861.05, 2863.6, 2863.25, 2867.0, 2871.25, 28...
# 2          5633  [2428.05, 2437.05, 2450.9, 2452.85, 2453.0, 24...
# 3          6401  [3843.0, 3854.15, 3857.7, 3861.95, 3858.0, 385...
# 4         12289  [881.0, 878.95, 883.3, 880.8, 881.9, 883.2, 88...
# ..          ...                                                ...
# 314     7565569  [194.74, 195.59, 195.62, 195.65, 195.5, 195.67...
# 315     7707649  [279.35, 278.45, 278.35, 277.5, 277.2, 277.75,...
# 316     7712001  [141.25, 141.45, 141.65, 141.85, 142.1, 142.35...
# 317     7982337  [1451.25, 1458.05, 1457.6, 1460.75, 1460.95, 1...
# 318     8042241  [38.9, 38.8, 38.75, 38.65, 38.75, 39.0, 38.9, ...
#
# [319 rows x 2 columns]
# ...

# %%
a
# Out:
# array([[ 602.75,  600.75,  604.6 , ...,  520.8 ,  521.5 ,  521.5 ],
#        [2861.05, 2863.6 , 2863.25, ..., 3139.5 , 3133.7 , 3127.35],
#        [2428.05, 2437.05, 2450.9 , ..., 1732.9 , 1733.05, 1733.9 ],
#        ...,
#        [ 141.25,  141.45,  141.65, ...,  102.75,  102.95,  102.85],
#        [1451.25, 1458.05, 1457.6 , ..., 1383.2 , 1390.  , 1389.25],
#        [  38.9 ,   38.8 ,   38.75, ...,   33.3 ,   33.35,   33.3 ]])
