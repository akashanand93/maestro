# %%
import os
import sys
os.chdir('../')

# %%
from visualize import Visualize

# %%
import torch
import numpy as np
import json
from torchsummary import summary
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## DLinear

# %%
seq_len=336
pred_len=96
channels=319
individual=False
checkpoint = 'traffic_336_96_DLinear_custom_ftM_sl336_ll48_pl96_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0'

# %%
vis = Visualize(seq_len, pred_len, channels, individual, checkpoint)

# %%
vis.plot(100, [4, 3])
